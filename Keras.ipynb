# %% [markdown]
# <a href="https://colab.research.google.com/github/YEON2020/to_localtest/blob/main/Keras.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install tensorflow

# %%
pip install keras

# %%
from keras.models import Sequential # keras의 models과 layers라는 이름을 가진 라이브러리 내의 Sequential과 Dense라는 오브젝트를 사용하기 위해 위 모델들을 임포트 시켜줍니다.
from keras.layers import Dense
import numpy as np #umpy의 기능들을 사용하기 위해 numpy도 임포트를 시켜주었고, 이제부터 numpy의 기능들을 불러올때는 간결하게 'np'만 사용하여 간단하게 불러줄 것입니다. ex) np.array()

x = np.array([1,2,3,4,5])
y = np.array([1,2,3,4,5])

model = Sequential()
model.add(Dense(5, input_dim=1, activation='relu'))

model.add(Dense(3))
model.add(Dense(1))

model.compile(loss='mse', optimizer='adam')
model.fit(x, y, epochs=100, batch_size = 1)

mse = model.evaluate(x, y, batch_size = 1)
print('mse : ', mse)
# Out:
# Epoch 1/100
# 5/5 [==============================] - 1s 4ms/step - loss: 13.7788
# Epoch 2/100
# 5/5 [==============================] - 0s 3ms/step - loss: 13.3484
# Epoch 3/100
# 5/5 [==============================] - 0s 3ms/step - loss: 12.9699
# Epoch 4/100
# 5/5 [==============================] - 0s 3ms/step - loss: 12.6966
# Epoch 5/100
# 5/5 [==============================] - 0s 3ms/step - loss: 12.2924
# Epoch 6/100
# 5/5 [==============================] - 0s 3ms/step - loss: 11.9067
# Epoch 7/100
# 5/5 [==============================] - 0s 3ms/step - loss: 11.5754
# Epoch 8/100
# 5/5 [==============================] - 0s 3ms/step - loss: 11.2777
# Epoch 9/100
# 5/5 [==============================] - 0s 3ms/step - loss: 10.9491
# Epoch 10/100
# 5/5 [==============================] - 0s 3ms/step - loss: 10.5740
# Epoch 11/100
# 5/5 [==============================] - 0s 3ms/step - loss: 10.2651
# Epoch 12/100
# 5/5 [==============================] - 0s 3ms/step - loss: 9.9080
# ...
